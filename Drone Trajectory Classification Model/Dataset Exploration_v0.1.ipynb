# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Meet/Projects/Project_6_Icarus_Autonomous Drone Navigation Research/Drone Trajectory Classification Model/Dataset/Drone onboard multi-modal sensor dataset for complex outdoor scenarios.csv')
data.head()
# Out:
#    flight  seq   uid   timestamp flight_logic_state  wind_speed  wind_angle  \
# 0       1    1  a3d9  1720598267         Idle-Hover        1.06          42
# 1       1    2  a3d9  1720598267         Idle-Hover        1.06          42
# 2       1    3  a3d9  1720598267         Idle-Hover        1.39          25
# 3       1    4  a3d9  1720598268         Idle-Hover        1.39          25
# 4       1    5  a3d9  1720598268         Idle-Hover        1.49          15
#
#    battery_voltage  battery_current  position_x  ...  linear_acceleration_y  \
# 0            51339              806   33.415298  ...              -0.001612
# 1            51339              806   33.415298  ...              -0.004273
# 2            51339              808   33.415298  ...              -0.001145
# 3            51339              808   33.415298  ...              -0.004068
# 4            51331              808   33.415298  ...              -0.004637
#
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         flight     seq   uid   timestamp flight_logic_state  wind_speed  \
# 0            1       1  a3d9  1720598267         Idle-Hover        1.06
# 1            1       2  a3d9  1720598267         Idle-Hover        1.06
# 2            1       3  a3d9  1720598267         Idle-Hover        1.39
# 3            1       4  a3d9  1720598268         Idle-Hover        1.39
# 4            1       5  a3d9  1720598268         Idle-Hover        1.49
# ...        ...     ...   ...         ...                ...         ...
# 276052      20  276053  a3d9  1722504229         Idle-Hover       10.75
# 276053      20  276054  a3d9  1722504229         Idle-Hover        1.29
# 276054      20  276055  a3d9  1722504230         Idle-Hover        1.29
# 276055      20  276056  a3d9  1722504230         Idle-Hover        2.22
# 276056      20  276057  a3d9  1722504230         Idle-Hover        2.22
#
# ...
